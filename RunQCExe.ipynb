# %%
#Make example data csv and use it to run QCExeExample. Data from generated csv will be used to create an html 
#page with graphs corresponding to the variables in ExampleData.csv

#MakeExampleData.ipynb uses a pre-existing csv generated using the same notebook. The distribution, mean, and standard deviation
#for each variable are determined and used to generate a new set of data. This data is put in to the output file,
#ExampleData.csv.

# %run MakeExampleData.ipynb
# %run QCExeTesting.ipynb
# Out:
# subject_id
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_2756\1840009000.py:105, in <module>
#     102 df_col = df_example[col].dropna()
#     103 try:
#     104    # Find best fit distribution
# --> 105     best_distibutions = best_fit_distribution(df_col, 200)
#     106     best_dist = best_distibutions[0]
#     108     col_to_append = make_distribution(best_dist[0].name,best_dist[1]) #make distribution
#
# File ~\AppData\Local\Temp\ipykernel_2756\1840009000.py:36, in best_fit_distribution(data, bins)
#      33 warnings.filterwarnings('ignore')
#      35 # fit dist to data
# ---> 36 params = distribution.fit(data)
#      38 # Separate parts of parameters
#      39 arg = params[:-2]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:63, in _call_super_mom.<locals>.wrapper(self, *args, **kwds)
#      61     return super(type(self), self).fit(*args, **kwds)
#      62 else:
# ---> 63     return fun(self, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:6797, in pearson3_gen.fit(self, data, *args, **kwds)
#    6793     raise NotImplementedError("Fit `method='MM'` is not available for "
#    6794                               "the Pearson3 distribution. Please try "
#    6795                               "the default `method='MLE'`.")
#    6796 else:
# -> 6797     return super(type(self), self).fit(data, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:2530, in rv_continuous.fit(self, data, *args, **kwds)
#    2524     raise TypeError("Unknown arguments: %s." % kwds)
#    2526 # In some cases, method of moments can be done with fsolve/root
#    2527 # instead of an optimizer, but sometimes no solution exists,
#    2528 # especially when the user fixes parameters. Minimizing the sum
#    2529 # of squares of the error generalizes to these cases.
# -> 2530 vals = optimizer(func, x0, args=(ravel(data),), disp=0)
#    2531 obj = func(vals, data)
#    2533 if restore is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_optimize.py:622, in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     513 """
#     514 Minimize a function using the downhill simplex algorithm.
#     515
#    (...)
#     612
#     613 """
#     614 opts = {'xatol': xtol,
#     615         'fatol': ftol,
#     616         'maxiter': maxiter,
#    (...)
#     619         'return_all': retall,
#     620         'initial_simplex': initial_simplex}
# --> 622 res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     623 if full_output:
#     624     retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_optimize.py:874, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     872     pass
#     873 finally:
# --> 874     ind = np.argsort(fsim)
#     875     sim = np.take(sim, ind, 0)
#     876     fsim = np.take(fsim, ind, 0)
#
# File <__array_function__ internals>:180, in argsort(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1120, in argsort(a, axis, kind, order)
#    1012 @array_function_dispatch(_argsort_dispatcher)
#    1013 def argsort(a, axis=-1, kind=None, order=None):
#    1014     """
#    1015     Returns the indices that would sort an array.
#    1016
#    (...)
#    1118
#    1119     """
# -> 1120     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 get_ipython().run_line_magic('run', 'MakeExampleData.ipynb')
#       2 get_ipython().run_line_magic('run', 'QCExeTesting.ipynb')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:2204, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2202     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2203 with self.builtin_trap:
# -> 2204     result = fn(*args, **kwargs)
#    2205 return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\magics\execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:2705, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2703 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2704 if raise_exceptions:
# -> 2705     result.raise_error()
#    2706 elif not result.success:
#    2707     break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:224, in ExecutionResult.raise_error(self)
#     222     raise self.error_before_exec
#     223 if self.error_in_exec is not None:
# --> 224     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_2756\1840009000.py:105, in <module>
#     102 df_col = df_example[col].dropna()
#     103 try:
#     104    # Find best fit distribution
# --> 105     best_distibutions = best_fit_distribution(df_col, 200)
#     106     best_dist = best_distibutions[0]
#     108     col_to_append = make_distribution(best_dist[0].name,best_dist[1]) #make distribution
#
# File ~\AppData\Local\Temp\ipykernel_2756\1840009000.py:36, in best_fit_distribution(data, bins)
#      33 warnings.filterwarnings('ignore')
#      35 # fit dist to data
# ---> 36 params = distribution.fit(data)
#      38 # Separate parts of parameters
#      39 arg = params[:-2]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:63, in _call_super_mom.<locals>.wrapper(self, *args, **kwds)
#      61     return super(type(self), self).fit(*args, **kwds)
#      62 else:
# ---> 63     return fun(self, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_continuous_distns.py:6797, in pearson3_gen.fit(self, data, *args, **kwds)
#    6793     raise NotImplementedError("Fit `method='MM'` is not available for "
#    6794                               "the Pearson3 distribution. Please try "
#    6795                               "the default `method='MLE'`.")
#    6796 else:
# -> 6797     return super(type(self), self).fit(data, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_distn_infrastructure.py:2530, in rv_continuous.fit(self, data, *args, **kwds)
#    2524     raise TypeError("Unknown arguments: %s." % kwds)
#    2526 # In some cases, method of moments can be done with fsolve/root
#    2527 # instead of an optimizer, but sometimes no solution exists,
#    2528 # especially when the user fixes parameters. Minimizing the sum
#    2529 # of squares of the error generalizes to these cases.
# -> 2530 vals = optimizer(func, x0, args=(ravel(data),), disp=0)
#    2531 obj = func(vals, data)
#    2533 if restore is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_optimize.py:622, in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     513 """
#     514 Minimize a function using the downhill simplex algorithm.
#     515
#    (...)
#     612
#     613 """
#     614 opts = {'xatol': xtol,
#     615         'fatol': ftol,
#     616         'maxiter': maxiter,
#    (...)
#     619         'return_all': retall,
#     620         'initial_simplex': initial_simplex}
# --> 622 res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     623 if full_output:
#     624     retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_optimize.py:874, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     872     pass
#     873 finally:
# --> 874     ind = np.argsort(fsim)
#     875     sim = np.take(sim, ind, 0)
#     876     fsim = np.take(fsim, ind, 0)
#
# File <__array_function__ internals>:180, in argsort(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1120, in argsort(a, axis, kind, order)
#    1012 @array_function_dispatch(_argsort_dispatcher)
#    1013 def argsort(a, axis=-1, kind=None, order=None):
#    1014     """
#    1015     Returns the indices that would sort an array.
#    1016
#    (...)
#    1118
#    1119     """
# -> 1120     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
